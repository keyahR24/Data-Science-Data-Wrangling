# %% [markdown]
# <a href="https://colab.research.google.com/github/keyahR24/data-science-prac-1/blob/main/DS_PRAC_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the data to the google colab
import pandas as pd
school = pd.read_csv("drive/MyDrive/school.csv")
print(school)
# Out:
#        ids        bday  enrolldate   expgradate  Rank  \
# 0    43783   3/22/1995         NaN          NaN   NaN
# 1    20278    1/1/1995         NaN          NaN   NaN
# 2    20389  12/31/1994         NaN          NaN   NaN
# 3    22820   12/1/1994         NaN          NaN   NaN
# 4    24559  11/10/1994         NaN          NaN   NaN
# ..     ...         ...         ...          ...   ...
# 430  34021   7/18/1987  1-Aug-2011  08-May-2017   4.0
# 431  40697   4/29/1987  1-Aug-2011  09-May-2016   4.0
# 432  34272         NaN  1-Aug-2011  09-May-2016   4.0
# 433  33628         NaN  1-Aug-2011  08-May-2017   4.0
# 434  39298         NaN  1-Aug-2011  08-May-2017   4.0
#
#                        Major  Gender  Athlete  Height  Weight  ...  English  \
# 0                        NaN     0.0        0   72.35     NaN  ...    88.24
# 1                 Philosophy     0.0        0   70.66  179.20  ...    89.45
# 2                        NaN     0.0        0   70.68  198.52  ...    96.73
# ...

# %%
#output the head or tail for the data
school.head(5)
school.tail(5)
# Out:
#        ids       bday  enrolldate   expgradate  Rank       Major  Gender  \
# 430  34021  7/18/1987  1-Aug-2011  08-May-2017   4.0  accounting     1.0
# 431  40697  4/29/1987  1-Aug-2011  09-May-2016   4.0         NaN     0.0
# 432  34272        NaN  1-Aug-2011  09-May-2016   4.0     nursing     0.0
# 433  33628        NaN  1-Aug-2011  08-May-2017   4.0     Nursing     1.0
# 434  39298        NaN  1-Aug-2011  08-May-2017   4.0         NaN     1.0
#
#      Athlete  Height  Weight  ...  English  Reading   Math  Writing     State  \
# 430        0     NaN     NaN  ...    87.72    84.99  65.31      NaN  In state
# 431        0   68.50  131.92  ...    91.01    86.87  70.25    82.67  In state
# 432        1   68.10  130.07  ...    81.05    85.76  58.16    81.87       NaN
# 433        1   69.27  157.26  ...    75.59    85.97  66.84    79.35  In state
# 434        1   66.68  152.33  ...    75.65    77.24  60.24    75.23  In state
#
# ...

# %%
#dimension for the data
school.shape
# Out:
# (435, 23)

# %%
#selection of columns of datasets
#single column
#school['Gender']
#multiple columns
school [['Math','Gender','Weight']]
# Out:
#       Math  Gender  Weight
# 0    60.02     0.0     NaN
# 1    70.19     0.0  179.20
# 2    71.20     0.0  198.52
# 3    55.89     1.0  198.34
# 4    65.52     1.0  128.17
# ..     ...     ...     ...
# 430  65.31     1.0     NaN
# 431  70.25     0.0  131.92
# 432  58.16     0.0  130.07
# 433  66.84     1.0  157.26
# 434  60.24     1.0  152.33
#
# [435 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Math'].plot(kind='hist', bins=20, title='Math')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Gender'].plot(kind='hist', bins=20, title='Gender')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Weight'].plot(kind='hist', bins=20, title='Weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
#getting the basic statistics/describing the data
school.describe()
# Out:
#                 ids        Rank      Gender     Athlete      Height  \
# count    435.000000  406.000000  426.000000  435.000000  408.000000
# mean   35279.022989    2.199507    0.521127    0.422989   68.031765
# std     8637.733605    1.098641    0.500141    0.494602    5.325655
# min    20183.000000    1.000000    0.000000    0.000000   55.000000
# 25%    28001.000000    1.000000    0.000000    0.000000   64.827500
# 50%    35350.000000    2.000000    1.000000    0.000000   67.570000
# 75%    42655.500000    3.000000    1.000000    1.000000   71.575000
# max    49947.000000    4.000000    1.000000    1.000000   84.410000
#
#            Weight     Smoking      Sprint     English     Reading        Math  \
# count  376.000000  411.000000  374.000000  409.000000  425.000000  422.000000
# mean   181.031569    0.430657    6.581933   82.787555   82.070800   65.468009
# std     42.749680    0.766324    1.227069    6.839803    7.661778    8.375930
# ...

# %%
#getting other statistics based on specific columns
school ['Math'].mean()
# Out:
# 65.46800947867298

# %%
#other possible methods for basic statistics
school ['Math'].median()
school ['Math'].mode()
school ['Math'].std()
school ['Math'].var()
# Out:
# 70.15619602841355

# %%
#checking for the missing data /NA in the dataset
school.isna().sum()
# Out:
# ids               0
# bday              8
# enrolldate       29
# expgradate       29
# Rank             29
# Major           159
# Gender            9
# Athlete           0
# Height           27
# Weight           59
# Smoking          24
# Sprint           61
# MileMinDur       43
# English          26
# Reading          10
# Math             13
# Writing          31
# State            27
# LiveOnCampus     21
# HowCommute      188
# CommuteTime     188
# SleepTime        32
# StudyTime        42
# dtype: int64

# %%
#replacing the missing values(this depends on preferred method)
school.fillna(0)
# Out:
#        ids        bday  enrolldate   expgradate  Rank  \
# 0    43783   3/22/1995           0            0   0.0
# 1    20278    1/1/1995           0            0   0.0
# 2    20389  12/31/1994           0            0   0.0
# 3    22820   12/1/1994           0            0   0.0
# 4    24559  11/10/1994           0            0   0.0
# ..     ...         ...         ...          ...   ...
# 430  34021   7/18/1987  1-Aug-2011  08-May-2017   4.0
# 431  40697   4/29/1987  1-Aug-2011  09-May-2016   4.0
# 432  34272           0  1-Aug-2011  09-May-2016   4.0
# 433  33628           0  1-Aug-2011  08-May-2017   4.0
# 434  39298           0  1-Aug-2011  08-May-2017   4.0
#
#                        Major  Gender  Athlete  Height  Weight  ...  English  \
# 0                          0     0.0        0   72.35    0.00  ...    88.24
# 1                 Philosophy     0.0        0   70.66  179.20  ...    89.45
# 2                          0     0.0        0   70.68  198.52  ...    96.73
# ...

# %%
#import the data to the google colab
import pandas as pd
school = pd.read_csv("drive/MyDrive/school.csv")
print(school)
# Out:
#        ids        bday  enrolldate   expgradate  Rank  \
# 0    43783   3/22/1995         NaN          NaN   NaN
# 1    20278    1/1/1995         NaN          NaN   NaN
# 2    20389  12/31/1994         NaN          NaN   NaN
# 3    22820   12/1/1994         NaN          NaN   NaN
# 4    24559  11/10/1994         NaN          NaN   NaN
# ..     ...         ...         ...          ...   ...
# 430  34021   7/18/1987  1-Aug-2011  08-May-2017   4.0
# 431  40697   4/29/1987  1-Aug-2011  09-May-2016   4.0
# 432  34272         NaN  1-Aug-2011  09-May-2016   4.0
# 433  33628         NaN  1-Aug-2011  08-May-2017   4.0
# 434  39298         NaN  1-Aug-2011  08-May-2017   4.0
#
#                        Major  Gender  Athlete  Height  Weight  ...  English  \
# 0                        NaN     0.0        0   72.35     NaN  ...    88.24
# 1                 Philosophy     0.0        0   70.66  179.20  ...    89.45
# 2                        NaN     0.0        0   70.68  198.52  ...    96.73
# ...

# %%
# Shape of the data
# From the output we see 435 rows by 23 columns
school.shape
# Out:
# (435, 23)

# %%
# Which columns are there?
school.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ids           435 non-null    int64
#  1   bday          427 non-null    object
#  2   enrolldate    406 non-null    object
#  3   expgradate    406 non-null    object
#  4   Rank          406 non-null    float64
#  5   Major         276 non-null    object
#  6   Gender        426 non-null    float64
#  7   Athlete       435 non-null    int64
#  8   Height        408 non-null    float64
#  9   Weight        376 non-null    float64
#  10  Smoking       411 non-null    float64
#  11  Sprint        374 non-null    float64
#  12  MileMinDur    392 non-null    object
#  13  English       409 non-null    float64
#  14  Reading       425 non-null    float64
#  15  Math          422 non-null    float64
#  16  Writing       404 non-null    float64
#  17  State         408 non-null    object
# ...

# %%
# Select columns
school['Rank']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 430    4.0
# 431    4.0
# 432    4.0
# 433    4.0
# 434    4.0
# Name: Rank, Length: 435, dtype: float64

# %%
# Select multiple columns
school[['Rank','Weight', 'Height', 'Major']]
# Out:
#      Rank  Weight  Height                    Major
# 0     NaN     NaN   72.35                      NaN
# 1     NaN  179.20   70.66               Philosophy
# 2     NaN  198.52   70.68                      NaN
# 3     NaN  198.34     NaN  business administration
# 4     NaN  128.17   67.43                      NaN
# ..    ...     ...     ...                      ...
# 430   4.0     NaN     NaN               accounting
# 431   4.0  131.92   68.50                      NaN
# 432   4.0  130.07   68.10                  nursing
# 433   4.0  157.26   69.27                  Nursing
# 434   4.0  152.33   66.68                      NaN
#
# [435 rows x 4 columns]

# %%
# Basic Stats
school[['Weight', 'Height', 'SleepTime','StudyTime']].mean()  # max(), min(), std(), median(), sum(), product()
# Out:
# Weight       181.031569
# Height        68.031765
# SleepTime      5.461538
# StudyTime      7.208651
# dtype: float64

# %%
# Cleaning, Do we have empties? Do we have unwanted columns, Do we have unwanted row?
school.isnull().sum()
# Missing Data... Less than 2%, its Fine
# Out:
# ids               0
# bday              8
# enrolldate       29
# expgradate       29
# Rank             29
# Major           159
# Gender            9
# Athlete           0
# Height           27
# Weight           59
# Smoking          24
# Sprint           61
# MileMinDur       43
# English          26
# Reading          10
# Math             13
# Writing          31
# State            27
# LiveOnCampus     21
# HowCommute      188
# CommuteTime     188
# SleepTime        32
# StudyTime        42
# dtype: int64
