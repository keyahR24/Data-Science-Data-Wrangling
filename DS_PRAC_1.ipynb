# %% [markdown]
# <a href="https://colab.research.google.com/github/keyahR24/Data-Science-Data-Wrangling/blob/main/DS_PRAC_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the data to the google colab
import pandas as pd
school = pd.read_csv("drive/MyDrive/school.csv")
print(school)
# Out:
#        ids        bday  enrolldate   expgradate  Rank  \
# 0    43783   3/22/1995         NaN          NaN   NaN
# 1    20278    1/1/1995         NaN          NaN   NaN
# 2    20389  12/31/1994         NaN          NaN   NaN
# 3    22820   12/1/1994         NaN          NaN   NaN
# 4    24559  11/10/1994         NaN          NaN   NaN
# ..     ...         ...         ...          ...   ...
# 430  34021   7/18/1987  1-Aug-2011  08-May-2017   4.0
# 431  40697   4/29/1987  1-Aug-2011  09-May-2016   4.0
# 432  34272         NaN  1-Aug-2011  09-May-2016   4.0
# 433  33628         NaN  1-Aug-2011  08-May-2017   4.0
# 434  39298         NaN  1-Aug-2011  08-May-2017   4.0
#
#                        Major  Gender  Athlete  Height  Weight  ...  English  \
# 0                        NaN     0.0        0   72.35     NaN  ...    88.24
# 1                 Philosophy     0.0        0   70.66  179.20  ...    89.45
# 2                        NaN     0.0        0   70.68  198.52  ...    96.73
# ...

# %%
#output the head or tail for the data
school.head(5)
school.tail(5)
# Out:
#        ids       bday  enrolldate   expgradate  Rank       Major  Gender  \
# 430  34021  7/18/1987  1-Aug-2011  08-May-2017   4.0  accounting     1.0
# 431  40697  4/29/1987  1-Aug-2011  09-May-2016   4.0         NaN     0.0
# 432  34272        NaN  1-Aug-2011  09-May-2016   4.0     nursing     0.0
# 433  33628        NaN  1-Aug-2011  08-May-2017   4.0     Nursing     1.0
# 434  39298        NaN  1-Aug-2011  08-May-2017   4.0         NaN     1.0
#
#      Athlete  Height  Weight  ...  English  Reading   Math  Writing     State  \
# 430        0     NaN     NaN  ...    87.72    84.99  65.31      NaN  In state
# 431        0   68.50  131.92  ...    91.01    86.87  70.25    82.67  In state
# 432        1   68.10  130.07  ...    81.05    85.76  58.16    81.87       NaN
# 433        1   69.27  157.26  ...    75.59    85.97  66.84    79.35  In state
# 434        1   66.68  152.33  ...    75.65    77.24  60.24    75.23  In state
#
# ...

# %%
#dimension for the data
school.shape
# Out:
# (435, 23)

# %%
#selection of columns of datasets
#single column
#school['Gender']
#multiple columns
school [['Math','Gender','Weight']]
# Out:
#       Math  Gender  Weight
# 0    60.02     0.0     NaN
# 1    70.19     0.0  179.20
# 2    71.20     0.0  198.52
# 3    55.89     1.0  198.34
# 4    65.52     1.0  128.17
# ..     ...     ...     ...
# 430  65.31     1.0     NaN
# 431  70.25     0.0  131.92
# 432  58.16     0.0  130.07
# 433  66.84     1.0  157.26
# 434  60.24     1.0  152.33
#
# [435 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Math'].plot(kind='hist', bins=20, title='Math')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Gender'].plot(kind='hist', bins=20, title='Gender')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Weight'].plot(kind='hist', bins=20, title='Weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
#getting the basic statistics/describing the data
school.describe()
# Out:
#                 ids        Rank      Gender     Athlete      Height  \
# count    435.000000  406.000000  426.000000  435.000000  408.000000
# mean   35279.022989    2.199507    0.521127    0.422989   68.031765
# std     8637.733605    1.098641    0.500141    0.494602    5.325655
# min    20183.000000    1.000000    0.000000    0.000000   55.000000
# 25%    28001.000000    1.000000    0.000000    0.000000   64.827500
# 50%    35350.000000    2.000000    1.000000    0.000000   67.570000
# 75%    42655.500000    3.000000    1.000000    1.000000   71.575000
# max    49947.000000    4.000000    1.000000    1.000000   84.410000
#
#            Weight     Smoking      Sprint     English     Reading        Math  \
# count  376.000000  411.000000  374.000000  409.000000  425.000000  422.000000
# mean   181.031569    0.430657    6.581933   82.787555   82.070800   65.468009
# std     42.749680    0.766324    1.227069    6.839803    7.661778    8.375930
# ...

# %%
#getting other statistics based on specific columns
school ['Math'].mean()
# Out:
# 65.46800947867298

# %%
#other possible methods for basic statistics
school ['Math'].median()
school ['Math'].mode()
school ['Math'].std()
school ['Math'].var()
# Out:
# 70.15619602841355

# %%
#checking for the missing data /NA in the dataset
school.isna().sum()
# Out:
# ids               0
# bday              8
# enrolldate       29
# expgradate       29
# Rank             29
# Major           159
# Gender            9
# Athlete           0
# Height           27
# Weight           59
# Smoking          24
# Sprint           61
# MileMinDur       43
# English          26
# Reading          10
# Math             13
# Writing          31
# State            27
# LiveOnCampus     21
# HowCommute      188
# CommuteTime     188
# SleepTime        32
# StudyTime        42
# dtype: int64

# %%
#Replacing the Missing values (This depend with prefered method)
#school.fillna(0)


school['Gender'].fillna(2.0,inplace=True)
# Out:
# <ipython-input-7-fb0dc58df65b>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   school['Gender'].fillna(2.0,inplace=True)

# %%
school['Gender'].isna().sum()
# Out:
# 0

# %%
#Impute using calculated values
school['Weight'].fillna(school['Weight'].mean(),inplace=True)
# Out:
# <ipython-input-9-eca67698c946>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   school['Weight'].fillna(school['Weight'].mean(),inplace=True)

# %%
#Replacing of values
school['Gender'].replace({2.0:"Neutral",1.0:"Female",0.0:"Male"},inplace=True)
school['Gender']
# Out:
# <ipython-input-10-9545b3f5c966>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   school['Gender'].replace({2.0:"Neutral",1.0:"Female",0.0:"Male"},inplace=True)
# 0        Male
# 1        Male
# 2        Male
# 3      Female
# 4      Female
#         ...
# 430    Female
# 431      Male
# 432      Male
# 433    Female
# 434    Female
# Name: Gender, Length: 435, dtype: object

# %%
#Droping the NA based on some columns
school.dropna(subset=['bday','Reading','Smoking'],inplace=True)
school.shape
# Out:
# (394, 23)

# %%
#Drop duplicates
school.drop_duplicates(inplace=True)
school.shape
# Out:
# (394, 23)

# %%
#Sampling data
school.sample(7)
# Out:
#        ids        bday  enrolldate   expgradate  Rank  \
# 287  32069   8/11/1993  6-Aug-2012  08-May-2017   3.0
# 184  46265   2/20/1995  5-Aug-2013  14-May-2018   2.0
# 281  27365   10/7/1993  6-Aug-2012  08-May-2017   3.0
# 299  40662   4/29/1993  6-Aug-2012  14-May-2018   3.0
# 83   22069  12/10/1994  4-Aug-2014  11-May-2020   1.0
# 348  48295   1/25/1991  6-Aug-2012  14-May-2018   3.0
# 405  37713    6/4/1990  1-Aug-2011  09-May-2016   4.0
#
#                              Major  Gender  Athlete  Height  Weight  ...  \
# 287                   film studies    Male        1   70.75  161.40  ...
# 184                       bio tech    Male        1   69.97  172.91  ...
# 281                       poli sci  Female        0   74.40  162.16  ...
# 299  English with minor in spanish    Male        1   76.12  220.77  ...
# 83                             NaN    Male        0   72.57  224.92  ...
# 348                            NaN  Female        0   64.87  203.55  ...
# ...

# %%
#finding the corelation
#school.corr(school[['Math','English','Reading']])
school[['Math','English','Reading']].corr()
# Out:
#              Math   English   Reading
# Math     1.000000  0.236584  0.530252
# English  0.236584  1.000000  0.332152
# Reading  0.530252  0.332152  1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Math'].plot(kind='hist', bins=20, title='Math')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['English'].plot(kind='hist', bins=20, title='English')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Reading'].plot(kind='hist', bins=20, title='Reading')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
#Group by function
#school.groupby(['Gender'])['Math'].mean()
school.groupby(['Gender']).size()
# Out:
# Gender
# Female     204
# Male       181
# Neutral      9
# dtype: int64

# %%
#Grouping using different variables
school.groupby(['Gender','Smoking','State'])[['Math','English','Reading']].mean()
# Out:
#                                    Math    English    Reading
# Gender  Smoking State
# Female  0.0     In state      64.303093  82.546392  82.081600
#                 Out of state  65.323429  83.519429  83.245556
#         1.0     In state      59.438571  82.210769  80.315714
#                 Out of state  69.738571  81.831429  83.658571
#         2.0     In state      65.111667  83.726400  83.318462
#                 Out of state  56.915714  84.318333  77.997500
# Male    0.0     In state      67.743564  83.946211  82.378667
#                 Out of state  63.599565  80.174000  80.852083
#         1.0     In state      67.256667  80.100833  84.059167
#                 Out of state  54.120000  87.730000  80.760000
#         2.0     In state      65.437273  82.023810  78.500000
#                 Out of state  66.561429  81.895714  82.948571
# Neutral 0.0     In state      68.434000  80.007500  82.788000
#                 Out of state  70.960000  87.150000  91.860000
# ...

# %%
#Checking for the smallest values based on a column
school.nsmallest(5,'Math')
# Out:
#        ids       bday  enrolldate   expgradate  Rank                  Major  \
# 72   44517  3/11/1995  4-Aug-2014  11-May-2020   1.0  Environmental Science
# 79   49155  1/13/1995  4-Aug-2014  11-May-2020   1.0                English
# 415  48958  1/17/1990  1-Aug-2011  09-May-2016   4.0              Fein Arts
# 114  43610  3/23/1994  4-Aug-2014  11-May-2020   1.0             Studio art
# 342  35681  6/28/1991  6-Aug-2012  14-May-2018   3.0            Arcitecture
#
#      Gender  Athlete  Height  Weight  ...  English  Reading   Math  Writing  \
# 72   Female        1   66.07  137.00  ...    69.81    70.58  35.32    70.73
# 79   Female        0   62.20  186.84  ...    77.17    55.11  40.38    80.62
# 415  Female        1   66.14  158.98  ...    85.75    77.39  44.70    80.65
# 114  Female        0   69.70  216.06  ...    79.61    78.38  45.79    77.91
# 342  Female        0   60.84  106.97  ...    85.45    82.44  46.14    76.75
#
# ...

# %%
#Finding the largest values in a column
school.nlargest(5,'Math')
# Out:
#        ids        bday  enrolldate   expgradate  Rank  \
# 352  26034  10/24/1990  6-Aug-2012  08-May-2017   3.0
# 419  23340  11/26/1989  1-Aug-2011  08-May-2017   4.0
# 331  47122    2/7/1992  6-Aug-2012  14-May-2018   3.0
# 158  48942   1/16/1993  4-Aug-2014  13-May-2019   1.0
# 138  32219    8/9/1993  4-Aug-2014  11-May-2020   1.0
#
#                            Major  Gender  Athlete  Height  Weight  ...  \
# 352               aaaaaaaaaaaaaa  Female        1   66.63  153.12  ...
# 419                  AstronomyÂ   Female        1   64.46  134.77  ...
# 331                          NaN  Female        0   62.01  177.30  ...
# 158          english composition  Female        0   69.84  238.91  ...
# 138  Family and Consumer Science    Male        0   70.40  246.64  ...
#
#      English  Reading   Math  Writing         State  LiveOnCampus  HowCommute  \
# 352    89.29    96.80  93.78    88.77  Out of state           0.0         3.0
# ...

# %%
#Aggregating
school.agg({'Math':['mean','min','max','median','var']})
# Out:
#              Math
# mean    65.601391
# min     35.320000
# max     93.780000
# median  65.520000
# var     72.085696

# %%
#SOrting values
school.sort_values(by='Math',ascending=False).head(5)
# Out:
#        ids        bday  enrolldate   expgradate  Rank  \
# 352  26034  10/24/1990  6-Aug-2012  08-May-2017   3.0
# 419  23340  11/26/1989  1-Aug-2011  08-May-2017   4.0
# 331  47122    2/7/1992  6-Aug-2012  14-May-2018   3.0
# 158  48942   1/16/1993  4-Aug-2014  13-May-2019   1.0
# 138  32219    8/9/1993  4-Aug-2014  11-May-2020   1.0
#
#                            Major  Gender  Athlete  Height  Weight  ...  \
# 352               aaaaaaaaaaaaaa  Female        1   66.63  153.12  ...
# 419                  AstronomyÂ   Female        1   64.46  134.77  ...
# 331                          NaN  Female        0   62.01  177.30  ...
# 158          english composition  Female        0   69.84  238.91  ...
# 138  Family and Consumer Science    Male        0   70.40  246.64  ...
#
#      English  Reading   Math  Writing         State  LiveOnCampus  HowCommute  \
# 352    89.29    96.80  93.78    88.77  Out of state           0.0         3.0
# ...

# %%
school = school.assign(BMI=school['Weight']/((school['Height']/100)**2))
school.head(5)
# Out:
#      ids        bday enrolldate expgradate  Rank         Major  Gender  \
# 0  43783   3/22/1995        NaN        NaN   NaN           NaN    Male
# 1  20278    1/1/1995        NaN        NaN   NaN    Philosophy    Male
# 2  20389  12/31/1994        NaN        NaN   NaN           NaN    Male
# 4  24559  11/10/1994        NaN        NaN   NaN           NaN  Female
# 6  33312   7/27/1994        NaN        NaN   NaN  Anthropology    Male
#
#    Athlete  Height      Weight  ...  Reading   Math Writing         State  \
# 0        0   72.35  181.031569  ...    81.50  60.02   81.44      In state
# 1        0   70.66  179.200000  ...    85.25  70.19   73.27           NaN
# 2        0   70.68  198.520000  ...    86.88  71.20   84.24      In state
# 4        1   67.43  128.170000  ...    77.30  65.52   80.45  Out of state
# 6        1   68.56  163.960000  ...    87.53  76.71   70.79      In state
#
#    LiveOnCampus  HowCommute  CommuteTime SleepTime  StudyTime         BMI
# ...

# %%
school = school.assign(Total_var=school[['Math','English','Reading']].fillna(0).sum())
school.head(5)
# Out:
#      ids        bday enrolldate expgradate  Rank         Major  Gender  \
# 0  43783   3/22/1995        NaN        NaN   NaN           NaN    Male
# 1  20278    1/1/1995        NaN        NaN   NaN    Philosophy    Male
# 2  20389  12/31/1994        NaN        NaN   NaN           NaN    Male
# 4  24559  11/10/1994        NaN        NaN   NaN           NaN  Female
# 6  33312   7/27/1994        NaN        NaN   NaN  Anthropology    Male
#
#    Athlete  Height      Weight  ...   Math  Writing         State  \
# 0        0   72.35  181.031569  ...  60.02    81.44      In state
# 1        0   70.66  179.200000  ...  70.19    73.27           NaN
# 2        0   70.68  198.520000  ...  71.20    84.24      In state
# 4        1   67.43  128.170000  ...  65.52    80.45  Out of state
# 6        1   68.56  163.960000  ...  76.71    70.79      In state
#
#    LiveOnCampus  HowCommute  CommuteTime  SleepTime StudyTime         BMI  \
# ...

# %%
#import the data to the google colab
import pandas as pd
school = pd.read_csv("drive/MyDrive/school.csv")
print(school)
# Out:
#        ids        bday  enrolldate   expgradate  Rank  \
# 0    43783   3/22/1995         NaN          NaN   NaN
# 1    20278    1/1/1995         NaN          NaN   NaN
# 2    20389  12/31/1994         NaN          NaN   NaN
# 3    22820   12/1/1994         NaN          NaN   NaN
# 4    24559  11/10/1994         NaN          NaN   NaN
# ..     ...         ...         ...          ...   ...
# 430  34021   7/18/1987  1-Aug-2011  08-May-2017   4.0
# 431  40697   4/29/1987  1-Aug-2011  09-May-2016   4.0
# 432  34272         NaN  1-Aug-2011  09-May-2016   4.0
# 433  33628         NaN  1-Aug-2011  08-May-2017   4.0
# 434  39298         NaN  1-Aug-2011  08-May-2017   4.0
#
#                        Major  Gender  Athlete  Height  Weight  Smoking  \
# 0                        NaN     0.0        0   72.35     NaN      0.0
# 1                 Philosophy     0.0        0   70.66  179.20      0.0
# 2                        NaN     0.0        0   70.68  198.52      0.0
# ...

# %%
#add a new column
import numpy as np
pd.set_option('display.max_columns', None)
school['performance'] = numpy.where(school['Math']>=65,"Passed","Failed")
school.head(2)
# Out:
#      ids       bday enrolldate expgradate  Rank       Major  Gender  Athlete  \
# 0  43783  3/22/1995        NaN        NaN   NaN         NaN     0.0        0
# 1  20278   1/1/1995        NaN        NaN   NaN  Philosophy     0.0        0
#
#    Height  Weight  Smoking  Sprint MileMinDur  English  Reading   Math  \
# 0   72.35     NaN      0.0   7.978        NaN    88.24    81.50  60.02
# 1   70.66   179.2      0.0   8.004    0:06:21    89.45    85.25  70.19
#
#    Writing     State  LiveOnCampus  HowCommute  CommuteTime  SleepTime  \
# 0    81.44  In state           1.0         NaN          NaN        7.0
# 1    73.27       NaN           1.0         NaN          NaN        5.0
#
#    StudyTime performance
# 0        1.0      Failed
# 1        2.0      Passed

# %%
school = school.assign(NewVar_Total= lambda school: school.English+school.Reading)
school.head(10)
school['NewVar_Total']
# Out:
# 0      169.74
# 1      174.70
# 2      183.61
# 3      162.74
# 4      159.91
#         ...
# 430    172.71
# 431    177.88
# 432    166.81
# 433    161.56
# 434    152.89
# Name: NewVar_Total, Length: 435, dtype: float64

# %%
school['Weight'].head(5)
# Out:
# 0       NaN
# 1    179.20
# 2    198.52
# 3    198.34
# 4    128.17
# Name: Weight, dtype: float64

# %%
#creating own function
def myfxn(x) :
    ans = 0.4563*x
    return ans

myfxn(school['Weight']).head(5)
#school['Weight'] =school['Weight'].apply(myfxn)
school.head(5)
# Out:
#      ids        bday enrolldate expgradate  Rank                    Major  \
# 0  43783   3/22/1995        NaN        NaN   NaN                      NaN
# 1  20278    1/1/1995        NaN        NaN   NaN               Philosophy
# 2  20389  12/31/1994        NaN        NaN   NaN                      NaN
# 3  22820   12/1/1994        NaN        NaN   NaN  business administration
# 4  24559  11/10/1994        NaN        NaN   NaN                      NaN
#
#    Gender  Athlete  Height     Weight  Smoking  Sprint MileMinDur  English  \
# 0     0.0        0   72.35        NaN      0.0   7.978        NaN    88.24
# 1     0.0        0   70.66  81.768960      0.0   8.004    0:06:21    89.45
# 2     0.0        0   70.68  90.584676      0.0     NaN    0:07:00    96.73
# 3     1.0        0     NaN  90.502542      NaN   8.473    0:12:44    74.06
# 4     1.0        1   67.43  58.483971      2.0     NaN    0:06:25    82.61
#
#    Reading   Math  Writing         State  LiveOnCampus  HowCommute  \
# ...

# %%
school['Gender'].fillna(2.0,inplace=True)
# Out:
# <ipython-input-18-81459e7a501a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   school['Gender'].fillna(2.0,inplace=True)

# %%
#seaborn and matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
school.groupby('Gender').size().plot(kind='pie',autopct = '%2.2f%%',explode = (0.1,0.1,0.4))
# Out:
# <Axes: >

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#seaborn and matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('Solarize_Light2')
school.groupby('Gender').size().plot(kind='pie',autopct = '%2.2f%%',explode = (0.1,0.1,0.4))
# Out:
# <Axes: >

# %%
#SAVE THE CLEANED DATA
school.to_csv('MyNewSchoolData.csv')
